# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\rajul'

# %%
salesdata=pd.read_csv(r"C:\Users\rajul\Sales_data .1.csv")

# %%
salesdata
# Out:
#               Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0       26-11-2013   26  November  2013            19     Youth (<25)
# 1       26-11-2015   26  November  2015            19     Youth (<25)
# 2       23-03-2014   23     March  2014            49  Adults (35-64)
# 3       23-03-2016   23     March  2016            49  Adults (35-64)
# 4       15-05-2014   15       May  2014            47  Adults (35-64)
# ...            ...  ...       ...   ...           ...             ...
# 113031  12-04-2016   12     April  2016            41  Adults (35-64)
# 113032  02-04-2014    2     April  2014            18     Youth (<25)
# 113033  02-04-2016    2     April  2016            18     Youth (<25)
# 113034  04-03-2014    4     March  2014            37  Adults (35-64)
# 113035  04-03-2016    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %% [markdown]
# # Understanding the Databse

# %% [markdown]
# ## Extracting information about all the columns available in Database

# %%
salesdata.columns
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue'],
#       dtype='object')

# %% [markdown]
# ## Extracting First 5 Rows in Databse

# %%
salesdata.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  26-11-2013   26  November  2013            19     Youth (<25)
# 1  26-11-2015   26  November  2015            19     Youth (<25)
# 2  23-03-2014   23     March  2014            49  Adults (35-64)
# 3  23-03-2016   23     March  2016            49  Adults (35-64)
# 4  15-05-2014   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %% [markdown]
# ## Extracting last 5 Rows in Database

# %%
salesdata.tail()
# Out:
#               Date  Day  Month  Year  Customer_Age       Age_Group  \
# 113031  12-04-2016   12  April  2016            41  Adults (35-64)
# 113032  02-04-2014    2  April  2014            18     Youth (<25)
# 113033  02-04-2016    2  April  2016            18     Youth (<25)
# 113034  04-03-2014    4  March  2014            37  Adults (35-64)
# 113035  04-03-2016    4  March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country          State Product_Category  \
# 113031               M  United Kingdom        England         Clothing
# 113032               M       Australia     Queensland         Clothing
# 113033               M       Australia     Queensland         Clothing
# 113034               F          France  Seine (Paris)         Clothing
# 113035               F          France  Seine (Paris)         Clothing
#
#        Sub_Category          Product  Order_Quantity  Unit_Cost  Unit_Price  \
# ...

# %% [markdown]
# ## Counting the Data in Database(Columnwise)

# %%
salesdata.count()
# Out:
# Date                113036
# Day                 113036
# Month               113036
# Year                113036
# Customer_Age        113036
# Age_Group           113036
# Customer_Gender     113036
# Country             113036
# State               113036
# Product_Category    113036
# Sub_Category        113036
# Product             113036
# Order_Quantity      113036
# Unit_Cost           113036
# Unit_Price          113036
# Profit              113036
# Cost                113036
# Revenue             113036
# dtype: int64

# %% [markdown]
# ## Extracting information about Database

# %%
salesdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  object
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
# ...

# %% [markdown]
# ## Check for null values

# %%
salesdata.isnull().sum()
# Out:
# Date                0
# Day                 0
# Month               0
# Year                0
# Customer_Age        0
# Age_Group           0
# Customer_Gender     0
# Country             0
# State               0
# Product_Category    0
# Sub_Category        0
# Product             0
# Order_Quantity      0
# Unit_Cost           0
# Unit_Price          0
# Profit              0
# Cost                0
# Revenue             0
# dtype: int64

# %% [markdown]
# # Analyzing the data by using Statistics

# %% [markdown]
# ## Extracting Discriptive Statistics for whole Database

# %%
salesdata.describe()
# Out:
#                  Day           Year   Customer_Age  Order_Quantity  \
# count  113036.000000  113036.000000  113036.000000   113036.000000
# mean       15.665753    2014.401739      35.919212       11.901660
# std         8.781567       1.272510      11.021936        9.561857
# min         1.000000    2011.000000      17.000000        1.000000
# 25%         8.000000    2013.000000      28.000000        2.000000
# 50%        16.000000    2014.000000      35.000000       10.000000
# 75%        23.000000    2016.000000      43.000000       20.000000
# max        31.000000    2016.000000      87.000000       32.000000
#
#            Unit_Cost     Unit_Price         Profit           Cost  \
# count  113036.000000  113036.000000  113036.000000  113036.000000
# mean      267.296366     452.938427     285.051665     469.318695
# std       549.835483     922.071219     453.887443     884.866118
# min         1.000000       2.000000     -30.000000       1.000000
# ...

# %% [markdown]
# ## Computation of Descriptive Statistics for individual variables

# %% [markdown]
# ## 1. calculation od descriptive statistics for "Unit Cost" Column

# %%
salesdata["Order_Quantity"].describe()
# Out:
# count    113036.000000
# mean         11.901660
# std           9.561857
# min           1.000000
# 25%           2.000000
# 50%          10.000000
# 75%          20.000000
# max          32.000000
# Name: Order_Quantity, dtype: float64

# %% [markdown]
# ## 2. calculation od descriptive statistics for "Unit Cost" Column

# %%
salesdata["Unit_Cost"].describe()
# Out:
# count    113036.000000
# mean        267.296366
# std         549.835483
# min           1.000000
# 25%           2.000000
# 50%           9.000000
# 75%          42.000000
# max        2171.000000
# Name: Unit_Cost, dtype: float64

# %% [markdown]
# ## 3. calculation od descriptive statistics for "Unit price" Column

# %%
salesdata["Unit_Price"].describe()
# Out:
# count    113036.000000
# mean        452.938427
# std         922.071219
# min           2.000000
# 25%           5.000000
# 50%          24.000000
# 75%          70.000000
# max        3578.000000
# Name: Unit_Price, dtype: float64

# %% [markdown]
# ## 4.calculation od descriptive statistics for "profit" Column

# %%
salesdata["Profit"].describe()
# Out:
# count    113036.000000
# mean        285.051665
# std         453.887443
# min         -30.000000
# 25%          29.000000
# 50%         101.000000
# 75%         358.000000
# max       15096.000000
# Name: Profit, dtype: float64

# %% [markdown]
# ## 5. calculation od descriptive statistics for "Cost" Column

# %%
salesdata["Cost"].describe()
# Out:
# count    113036.000000
# mean        469.318695
# std         884.866118
# min           1.000000
# 25%          28.000000
# 50%         108.000000
# 75%         432.000000
# max       42978.000000
# Name: Cost, dtype: float64

# %% [markdown]
# ## 6. calculation od descriptive statistics for "Revenue" Column

# %%
salesdata["Revenue"].describe()
# Out:
# count    113036.000000
# mean        754.370360
# std        1309.094674
# min           2.000000
# 25%          63.000000
# 50%         223.000000
# 75%         800.000000
# max       58074.000000
# Name: Revenue, dtype: float64

# %% [markdown]
# # Calculatin of Mean Value for Individual Columns

# %% [markdown]
# ## 1. Calculation of Mean Value for "Order Quantity"

# %%
salesdata["Order_Quantity"].mean()
# Out:
# 11.901659648253654

# %% [markdown]
# ## 2.Calculation of Mean Value for "Unit Cost"

# %%
salesdata["Unit_Cost"].mean()
# Out:
# 267.296365759581

# %% [markdown]
# ## 3. Calculation of Mean Value for "Unit Price"

# %%
salesdata["Unit_Price"].mean()
# Out:
# 452.9384266959199

# %% [markdown]
# ## 4.Calculation of Mean Value for "Profit"

# %%
salesdata["Profit"].mean()
# Out:
# 285.0516649562971

# %% [markdown]
# ## 5.Calculation of Mean Value for "Cost"

# %%
salesdata["Cost"].mean()
# Out:
# 469.3186949290492

# %% [markdown]
# ## 6. Calculation of Mean Value for "Revenue"

# %%
salesdata["Revenue"].mean()
# Out:
# 754.3703598853463

# %% [markdown]
# # Claculation of Median Value for all the columns

# %%
print(salesdata["Order_Quantity"].median())
print(salesdata["Unit_Cost"].median())
print(salesdata["Unit_Price"].median())
print(salesdata["Profit"].median())
print(salesdata["Cost"].median())
print(salesdata["Revenue"].median())
# Out:
# 10.0
# 9.0
# 24.0
# 101.0
# 108.0
# 223.0

# %% [markdown]
# ## Claculation of Mode Value for all the columns

# %%
print(salesdata["Unit_Cost"].mode())
print(salesdata["Unit_Price"].mode())
print(salesdata["Profit"].mode())
print(salesdata["Cost"].mode())
print(salesdata["Revenue"].mode())
# Out:
# 0    2
# Name: Unit_Cost, dtype: int64
# 0    5
# Name: Unit_Price, dtype: int64
# 0    3
# Name: Profit, dtype: int64
# 0    1252
# Name: Cost, dtype: int64
# 0    35
# Name: Revenue, dtype: int64

# %% [markdown]
# # Understanding The Distribution of Data

# %%
salesdata["Order_Quantity"].hist()
# Out:
# <Axes: >

# %%
salesdata["Unit_Cost"].hist()
# Out:
# <Axes: >

# %%
salesdata["Unit_Price"].hist()
# Out:
# <Axes: >

# %%
salesdata["Profit"].hist()
# Out:
# <Axes: >

# %%
salesdata["Cost"].hist()
# Out:
# <Axes: >

# %%
salesdata["Revenue"].hist()
# Out:
# <Axes: >

# %%
salesdata.hist(color = "k",
               bins = 30, 
               figsize = (15, 10))
plt.show()

# %%
correlation=(salesdata[["Order_Quantity","Unit_Cost"]]).corr()
print(correlation)
# Out:
#                 Order_Quantity  Unit_Cost
# Order_Quantity        1.000000  -0.515835
# Unit_Cost            -0.515835   1.000000

# %%
correlation=(salesdata[["Unit_Price", "Profit", "Cost", "Revenue"]]).corr()
print(correlation)
# Out:
#             Unit_Price    Profit      Cost   Revenue
# Unit_Price    1.000000  0.749870  0.826301  0.818522
# Profit        0.749870  1.000000  0.902233  0.956572
# Cost          0.826301  0.902233  1.000000  0.988758
# Revenue       0.818522  0.956572  0.988758  1.000000

# %%
sns.heatmap(correlation)
# Out:
# <Axes: >

# %%
correaltion=(salesdata[["Unit_Cost", "Unit_Price"]].corr())
sns.heatmap(correaltion)
# Out:
# <Axes: >

# %%
correlation=(salesdata[["Order_Quantity", "Unit_Cost"]].corr())
sns.heatmap(correlation)
# Out:
# <Axes: >

# %%
correlation=(salesdata[["Unit_Price", "Profit"]].corr())
sns.heatmap(correlation)
# Out:
# <Axes: >

# %%
correlation=(salesdata[["Cost", "Revenue"]].corr())
sns.heatmap(correlation)
# Out:
# <Axes: >

# %% [markdown]
# ## Categorical Data Analysis

# %%
salesdata
# Out:
#               Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0       26-11-2013   26  November  2013            19     Youth (<25)
# 1       26-11-2015   26  November  2015            19     Youth (<25)
# 2       23-03-2014   23     March  2014            49  Adults (35-64)
# 3       23-03-2016   23     March  2016            49  Adults (35-64)
# 4       15-05-2014   15       May  2014            47  Adults (35-64)
# ...            ...  ...       ...   ...           ...             ...
# 113031  12-04-2016   12     April  2016            41  Adults (35-64)
# 113032  02-04-2014    2     April  2014            18     Youth (<25)
# 113033  02-04-2016    2     April  2016            18     Youth (<25)
# 113034  04-03-2014    4     March  2014            37  Adults (35-64)
# 113035  04-03-2016    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
salesdata["Customer_Gender"].value_counts()
# Out:
# Customer_Gender
# M    58312
# F    54724
# Name: count, dtype: int64

# %%
salesdata["Customer_Gender"].value_counts().plot(kind='pie', figsize=(6,8))
# Out:
# <Axes: ylabel='count'>

# %%
salesdata["Customer_Gender"].value_counts().plot(kind='bar', figsize=(6,8))
# Out:
# <Axes: xlabel='Customer_Gender'>

# %%
salesdata["Sub_Category"].value_counts().plot(kind='bar', figsize=(6,8))
# Out:
# <Axes: xlabel='Sub_Category'>

# %%
salesdata["Sub_Category"].value_counts().plot(kind='line', figsize=(6,8))
# Out:
# <Axes: xlabel='Sub_Category'>

# %%
salesdata["Sub_Category"].value_counts().plot(kind='pie', figsize=(6,6))
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## Outlyer

# %%
sns.boxplot(salesdata["Order_Quantity"])
# Out:
# <Axes: ylabel='Order_Quantity'>

# %%
sns.boxplot(salesdata["Unit_Cost"])
# Out:
# <Axes: ylabel='Unit_Cost'>

# %%
sns.boxplot(salesdata["Unit_Price"])
# Out:
# <Axes: ylabel='Unit_Price'>

# %%
sns.boxplot(salesdata["Profit"])
# Out:
# <Axes: ylabel='Profit'>

# %%
sns.boxplot(salesdata["Cost"])
# Out:
# <Axes: ylabel='Cost'>

# %%
sns.boxplot(salesdata["Revenue"])
# Out:
# <Axes: ylabel='Revenue'>
